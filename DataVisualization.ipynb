# %%
from PIL import Image as im
im.MAX_IMAGE_PIXELS = None
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
# %matplotlib inline

# %%
test_data = np.load('/content/drive/MyDrive/Meta_learning_research/Notebooks/samples/Alexander/test_data_200.npy')
test_label = np.load('/content/drive/MyDrive/Meta_learning_research/Notebooks/samples/Alexander/test_label_200.npy')

print(test_data.shape, test_label.shape)
# Out:
# (200, 224, 224, 8) (200, 224, 224, 1)

# %%
rando_ind = 33

# %%
fig, axs = plt.subplots(2, 4,figsize=(20,10))
fig.tight_layout()
labels = ["a","b","c","d","e","f","g","h"]
count = 0
img_order = [3,0,1,2,4,5,6,7]
for ax in axs.flat:
  image = test[rando_ind,:,:,img_order[count]]
  im = ax.imshow(image)
  ax.set_xlabel("("+labels[count]+")", fontsize = 16) # X label
  count = count + 1

fig.colorbar(im, ax=axs.ravel().tolist() , shrink=0.9)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.xlabel("(i)", fontsize = 16)
plt.imshow(test_label[rando_ind][:,:,0])
plt.colorbar()
